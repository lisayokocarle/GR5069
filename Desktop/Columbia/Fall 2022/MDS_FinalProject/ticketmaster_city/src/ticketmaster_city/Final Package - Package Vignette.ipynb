# %%
### installing dependencies and package from Test Pypi
# !poetry add pandas
# !poetry add pytest
# !poetry add requests
# !pip install -i https://test.pypi.org/simple/ ticketmaster-city --upgrade
# Out:
# The following packages are already present in the pyproject.toml and will be skipped:
#
#   • pandas
#
# If you want to update it to the latest compatible version, you can use `poetry update package`.
# If you prefer to upgrade it to the latest available version, you can use `poetry add package@latest`.
#
#
# Could not find a matching version of package as
# The following packages are already present in the pyproject.toml and will be skipped:
#
#   • pytest
#
# If you want to update it to the latest compatible version, you can use `poetry update package`.
# If you prefer to upgrade it to the latest available version, you can use `poetry add package@latest`.
#
# Nothing to add.
# The following packages are already present in the pyproject.toml and will be skipped:
#
#   • requests
#
# If you want to update it to the latest compatible version, you can use `poetry update package`.
# If you prefer to upgrade it to the latest available version, you can use `poetry add package@latest`.
#
# Nothing to add.
# Looking in indexes: https://test.pypi.org/simple/
# Requirement already satisfied: ticketmaster-city in /Users/lisayokocarle/Library/Caches/pypoetry/virtualenvs/mds-6fCZ5dbA-py3.11/lib/python3.11/site-packages (1.0.0)
# Requirement already satisfied: pandas<2.0.0,>=1.5.2 in /Users/lisayokocarle/Library/Caches/pypoetry/virtualenvs/mds-6fCZ5dbA-py3.11/lib/python3.11/site-packages (from ticketmaster-city) (1.5.2)
# Requirement already satisfied: pytest<8.0.0,>=7.2.0 in /Users/lisayokocarle/Library/Caches/pypoetry/virtualenvs/mds-6fCZ5dbA-py3.11/lib/python3.11/site-packages (from ticketmaster-city) (7.2.0)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /Users/lisayokocarle/Library/Caches/pypoetry/virtualenvs/mds-6fCZ5dbA-py3.11/lib/python3.11/site-packages (from ticketmaster-city) (2.28.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/lisayokocarle/Library/Caches/pypoetry/virtualenvs/mds-6fCZ5dbA-py3.11/lib/python3.11/site-packages (from pandas<2.0.0,>=1.5.2->ticketmaster-city) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/lisayokocarle/Library/Caches/pypoetry/virtualenvs/mds-6fCZ5dbA-py3.11/lib/python3.11/site-packages (from pandas<2.0.0,>=1.5.2->ticketmaster-city) (2022.6)
# Requirement already satisfied: numpy>=1.21.0 in /Users/lisayokocarle/Library/Caches/pypoetry/virtualenvs/mds-6fCZ5dbA-py3.11/lib/python3.11/site-packages (from pandas<2.0.0,>=1.5.2->ticketmaster-city) (1.23.5)
# Requirement already satisfied: attrs>=19.2.0 in /Users/lisayokocarle/Library/Caches/pypoetry/virtualenvs/mds-6fCZ5dbA-py3.11/lib/python3.11/site-packages (from pytest<8.0.0,>=7.2.0->ticketmaster-city) (22.1.0)
# Requirement already satisfied: iniconfig in /Users/lisayokocarle/Library/Caches/pypoetry/virtualenvs/mds-6fCZ5dbA-py3.11/lib/python3.11/site-packages (from pytest<8.0.0,>=7.2.0->ticketmaster-city) (1.1.1)
# Requirement already satisfied: packaging in /Users/lisayokocarle/Library/Caches/pypoetry/virtualenvs/mds-6fCZ5dbA-py3.11/lib/python3.11/site-packages (from pytest<8.0.0,>=7.2.0->ticketmaster-city) (21.3)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Users/lisayokocarle/Library/Caches/pypoetry/virtualenvs/mds-6fCZ5dbA-py3.11/lib/python3.11/site-packages (from pytest<8.0.0,>=7.2.0->ticketmaster-city) (1.0.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/lisayokocarle/Library/Caches/pypoetry/virtualenvs/mds-6fCZ5dbA-py3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.28.1->ticketmaster-city) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/lisayokocarle/Library/Caches/pypoetry/virtualenvs/mds-6fCZ5dbA-py3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.28.1->ticketmaster-city) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/lisayokocarle/Library/Caches/pypoetry/virtualenvs/mds-6fCZ5dbA-py3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.28.1->ticketmaster-city) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/lisayokocarle/Library/Caches/pypoetry/virtualenvs/mds-6fCZ5dbA-py3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.28.1->ticketmaster-city) (2022.12.7)
# Requirement already satisfied: six>=1.5 in /Users/lisayokocarle/Library/Caches/pypoetry/virtualenvs/mds-6fCZ5dbA-py3.11/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.5.2->ticketmaster-city) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/lisayokocarle/Library/Caches/pypoetry/virtualenvs/mds-6fCZ5dbA-py3.11/lib/python3.11/site-packages (from packaging->pytest<8.0.0,>=7.2.0->ticketmaster-city) (3.0.9)

# %%
### importing API key as environmental variable
import os

from dotenv import load_dotenv
load_dotenv()

key=os.getenv('CONSUMER_KEY')

# %%
###importing module from package 
from ticketmaster_city import ticketmaster_city

# %%
###creating object from class and showing string output of class
LA = ticketmaster_city.City(cityname = 'Los Angeles', password = key)
print(LA)
# Out:
# Los Angeles

# %%
### showing class methods
LA.genres()
# Out:
# {'Other': 1, 'Rock': 8, 'Pop': 8, 'R&B': 1, 'Dance/Electronic': 2}

# %%
### showing other class methods 
LA.subgenres()
# Out:
# {'Other': 1,
#  'Pop': 10,
#  'K-Pop': 3,
#  'R&B': 1,
#  'Witchstep': 2,
#  'Alternative Rock': 2,
#  'Adult Contemporary': 1}

# %%
### showing other class methods
LA.events()
# Out:
# {'Junior H: Sad Boyz 4 Life Tour': 'Z7r9jZ1Adf8bv',
#  'blink-182 Tour 2023': 'vvG1IZ9fsXJvdF',
#  'AT&T Playoff Playlist Live!': 'vvG1IZ99k6P3a9',
#  'Stray Kids 2nd World Tour "MANIAC"': 'vvG1IZ94V7b71k',
#  'Noah Kahan: The Stick Season Tour': 'vvG10Z9b9ENfTc',
#  'In My Feelz Festival': 'vvG1IZ9pH8wkDJ',
#  'IGORRR with Melt-Banana & VOWWS': 'vvG10ZpcsiTvOL',
#  'IGORRR with Melt-Banana, & Otto Von Schirach': 'vvG10Z9b5jX6zV',
#  'Lindsey Stirling - Snow Waltz Tour': 'vvG1iZ93Lihxoh',
#  'Tove Lo - Dirt Femme Tour with Special Guest Slayyyter': 'vvG10Z9KVmGF6S',
#  'Joshua Bassett: The Complicated Tour': 'vvG10Z9bJHd0gb',
#  'An Evening with They Might Be Giants': 'vv1AaZA-4Gkd4H4S9',
#  "J.Y. Park Concert 'Groove Back' In LA": 'vvG10Z99BM20ZL',
#  'Harry Connick, Jr.': 'vvG1iZ93M0ZsHV',
#  'Lizzy McAlpine: The End of The Movie Tour': 'vvG10Z94imV_oV',
#  'Iggy Pop & The Losers': 'vvG10Z9bbejpi-'}

# %%
###showing api function when there are no concerts
ticketmaster_city.apiget(city = 'Los Angeles', password = key, keyword = 'Smino')
# Out:
# No concerts with those parameters!

# %%
###showing api function when there are concerts
ticketmaster_city.apiget(city= 'Chicago', password = key, keyword = "Smino")
# Out:
#                                 name   type              id   test  \
# 0  J.I.D & Smino - Luv Is 4ever Tour  event  vvG18Z9fb7C4jC  False
#
#                                                  url locale  \
# 0  https://concerts.livenation.com/jid-smino-luv-...  en-us
#
#                                               images  \
# 0  [{'ratio': '16_9', 'url': 'https://s1.ticketm....
#
#                                                sales  \
# 0  {'public': {'startDateTime': '2022-10-14T15:00...
#
#                                                dates  \
# 0  {'start': {'localDate': '2023-03-21', 'localTi...
#
#                                      classifications  ...  \
# 0  [{'primary': True, 'segment': {'id': 'KZFzniwn...  ...
#
#                                           pleaseNote  \
# 0  This is an ALL AGES event. Byline Bank Aragon ...
#
#                                          priceRanges  \
# 0  [{'type': 'standard', 'currency': 'USD', 'min'...
#
#                                             products  \
# 0  [{'name': 'Aragon Ballroom Fast Lane Pass -J.I...
#
#                                              seatmap accessibility  \
# 0  {'staticUrl': 'https://maps.ticketmaster.com/m...            {}
#
#                                          ticketLimit  \
# 0  {'info': 'There is a ticket limit of 8 for thi...
#
#                ageRestrictions                       ticketing  \
# 0  {'legalAgeEnforced': False}  {'safeTix': {'enabled': True}}
#
#                                               _links  \
# 0  {'self': {'href': '/discovery/v2/events/vvG18Z...
#
#                                            _embedded
# 0  {'venues': [{'name': 'Byline Bank Aragon Ballr...
#
# [1 rows x 23 columns]

# %%
###using df from api function to further look into the data
df1= ticketmaster_city.apiget(city = 'San Francisco', password = key)
df1.head()
# Out:
#                               name   type             id   test  \
# 0  Dead & Company - The Final Tour  event  G5vYZ9f93b4_x  False
# 1  Dead & Company - The Final Tour  event  G5vYZ94kPSN57  False
# 2  Dead & Company - The Final Tour  event  G5vYZ9f9oYgby  False
# 3                   Arctic Monkeys  event  G5vYZ9KsD2-G6  False
# 4                         Paramore  event  G5vYZ9pCpmeff  False
#
#                                                  url locale  \
# 0  https://www.ticketmaster.com/dead-company-the-...  en-us
# 1  https://www.ticketmaster.com/dead-company-the-...  en-us
# 2  https://www.ticketmaster.com/dead-company-the-...  en-us
# 3  https://www.ticketmaster.com/arctic-monkeys-sa...  en-us
# 4  https://www.ticketmaster.com/paramore-san-fran...  en-us
#
#                                               images  \
# 0  [{'ratio': '16_9', 'url': 'https://s1.ticketm....
# 1  [{'ratio': '16_9', 'url': 'https://s1.ticketm....
# 2  [{'ratio': '16_9', 'url': 'https://s1.ticketm....
# 3  [{'ratio': '16_9', 'url': 'https://s1.ticketm....
# 4  [{'ratio': '3_2', 'url': 'https://s1.ticketm.n...
#
#                                                sales  \
# 0  {'public': {'startDateTime': '2022-10-14T17:00...
# 1  {'public': {'startDateTime': '2022-10-21T17:00...
# 2  {'public': {'startDateTime': '2022-10-14T17:00...
# 3  {'public': {'startDateTime': '2022-10-07T17:00...
# 4  {'public': {'startDateTime': '2022-11-11T18:00...
#
#                                                dates  \
# 0  {'start': {'localDate': '2023-07-15', 'localTi...
# 1  {'start': {'localDate': '2023-07-16', 'localTi...
# 2  {'start': {'localDate': '2023-07-14', 'localTi...
# 3  {'start': {'localDate': '2023-09-26', 'localTi...
# 4  {'start': {'localDate': '2023-07-22', 'localTi...
#
#                                      classifications  ...       accessibility  \
# 0  [{'primary': True, 'segment': {'id': 'KZFzniwn...  ...  {'ticketLimit': 4}
# 1  [{'primary': True, 'segment': {'id': 'KZFzniwn...  ...  {'ticketLimit': 4}
# 2  [{'primary': True, 'segment': {'id': 'KZFzniwn...  ...  {'ticketLimit': 4}
# 3  [{'primary': True, 'segment': {'id': 'KZFzniwn...  ...                  {}
# 4  [{'primary': True, 'segment': {'id': 'KZFzniwn...  ...  {'ticketLimit': 8}
#
#                                          ticketLimit  \
# 0  {'info': 'There is an overall 4 ticket limit f...
# 1  {'info': 'There is an overall 4 ticket limit f...
# 2  {'info': 'There is an overall 4 ticket limit f...
# 3  {'info': 'There is an overall 6 ticket limit f...
# 4  {'info': 'There is a 4 ticket limit per housho...
#
#                ageRestrictions                       ticketing  \
# 0  {'legalAgeEnforced': False}  {'safeTix': {'enabled': True}}
# 1  {'legalAgeEnforced': False}  {'safeTix': {'enabled': True}}
# 2  {'legalAgeEnforced': False}  {'safeTix': {'enabled': True}}
# 3  {'legalAgeEnforced': False}  {'safeTix': {'enabled': True}}
# 4  {'legalAgeEnforced': False}  {'safeTix': {'enabled': True}}
#
#                                               _links  \
# 0  {'self': {'href': '/discovery/v2/events/G5vYZ9...
# 1  {'self': {'href': '/discovery/v2/events/G5vYZ9...
# 2  {'self': {'href': '/discovery/v2/events/G5vYZ9...
# 3  {'self': {'href': '/discovery/v2/events/G5vYZ9...
# 4  {'self': {'href': '/discovery/v2/events/G5vYZ9...
#
#                                            _embedded  \
# 0  {'venues': [{'name': 'Oracle Park', 'type': 'v...
# 1  {'venues': [{'name': 'Oracle Park', 'type': 'v...
# 2  {'venues': [{'name': 'Oracle Park', 'type': 'v...
# 3  {'venues': [{'name': 'Chase Center', 'type': '...
# 4  {'venues': [{'name': 'Chase Center', 'type': '...
#
#                                             products info pleaseNote outlets
# 0                                                NaN  NaN        NaN     NaN
# 1                                                NaN  NaN        NaN     NaN
# 2                                                NaN  NaN        NaN     NaN
# 3  [{'name': 'Chase Center Parking - Arctic Monke...  NaN        NaN     NaN
# 4  [{'name': 'Chase Center Parking - Paramore', '...  NaN        NaN     NaN
#
# [5 rows x 24 columns]

# %%
df2 = df1['sales']
dictionary = {}
for rows in df2:
    for key, value in rows.items():
        if key in dictionary.keys():
            dictionary[key].append(value)
        else:
            dictionary[key]=[value]

# %%
print(dictionary.keys())
# Out:
# dict_keys(['public', 'presales'])

# %%
dictionary['public']
# Out:
# [{'startDateTime': '2022-10-14T17:00:00Z',
#   'startTBD': False,
#   'startTBA': False,
#   'endDateTime': '2023-07-16T04:00:00Z'},
#  {'startDateTime': '2022-10-21T17:00:00Z',
#   'startTBD': False,
#   'startTBA': False,
#   'endDateTime': '2023-07-17T03:00:00Z'},
#  {'startDateTime': '2022-10-14T17:00:00Z',
#   'startTBD': False,
#   'startTBA': False,
#   'endDateTime': '2023-07-15T04:00:00Z'},
#  {'startDateTime': '2022-10-07T17:00:00Z',
#   'startTBD': False,
#   'startTBA': False,
#   'endDateTime': '2023-09-27T03:00:00Z'},
#  {'startDateTime': '2022-11-11T18:00:00Z',
#   'startTBD': False,
#   'startTBA': False,
#   'endDateTime': '2023-07-23T02:00:00Z'},
#  {'startDateTime': '2022-10-28T17:00:00Z',
#   'startTBD': False,
#   'startTBA': False,
#   'endDateTime': '2023-03-06T03:30:00Z'},
#  {'startDateTime': '2022-06-17T17:00:00Z',
#   'startTBD': False,
#   'startTBA': False,
#   'endDateTime': '2022-12-19T03:30:00Z'},
#  {'startDateTime': '2022-12-16T18:00:00Z',
#   'startTBD': False,
#   'startTBA': False,
#   'endDateTime': '2023-04-23T05:00:00Z'},
#  {'startDateTime': '2022-11-26T03:10:00Z',
#   'startTBD': False,
#   'startTBA': False,
#   'endDateTime': '2022-12-29T00:00:00Z'},
#  {'startDateTime': '2022-12-16T18:00:00Z',
#   'startTBD': False,
#   'startTBA': False,
#   'endDateTime': '2023-03-08T06:00:00Z'},
#  {'startDateTime': '1900-01-01T06:00:00Z',
#   'startTBD': False,
#   'startTBA': False,
#   'endDateTime': '2022-12-18T04:00:00Z'},
#  {'startDateTime': '2022-10-07T17:00:00Z',
#   'startTBD': False,
#   'startTBA': False,
#   'endDateTime': '2023-04-01T03:00:00Z'},
#  {'startDateTime': '2022-11-16T18:00:00Z',
#   'startTBD': False,
#   'startTBA': False,
#   'endDateTime': '2023-01-15T04:00:00Z'},
#  {'startDateTime': '2022-10-26T16:00:00Z',
#   'startTBD': False,
#   'startTBA': False,
#   'endDateTime': '2023-01-22T06:30:00Z'},
#  {'startDateTime': '2022-11-30T18:00:00Z',
#   'startTBD': False,
#   'startTBA': False,
#   'endDateTime': '2023-02-26T05:00:00Z'},
#  {'startDateTime': '2022-11-23T22:10:00Z',
#   'startTBD': False,
#   'startTBA': False,
#   'endDateTime': '2022-12-21T00:30:00Z'},
#  {'startDateTime': '2022-09-13T17:00:00Z',
#   'startTBD': False,
#   'startTBA': False,
#   'endDateTime': '2023-01-21T07:00:00Z'},
#  {'startDateTime': '2022-12-12T18:00:00Z',
#   'startTBD': False,
#   'startTBA': False,
#   'endDateTime': '2023-01-29T06:30:00Z'},
#  {'startDateTime': '2022-12-16T18:00:00Z',
#   'startTBD': False,
#   'startTBA': False,
#   'endDateTime': '2023-04-15T03:00:00Z'},
#  {'startDateTime': '2022-12-16T18:00:00Z',
#   'startTBD': False,
#   'startTBA': False,
#   'endDateTime': '2023-04-16T03:00:00Z'}]
